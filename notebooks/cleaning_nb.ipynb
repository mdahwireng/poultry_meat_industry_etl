# %% [markdown]
# # Import packages

# %%
import os
import pandas as pd
import difflib

# %% [markdown]
# # Change directory to one level up

# %%
os.getcwd()
# Out:
# 'C:\\Users\\kaaym\\Documents\\mike\\projects\\poultry_meat_industry_etl\\notebooks'

# %%
os.chdir('../')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\kaaym\\Documents\\mike\\projects\\poultry_meat_industry_etl'

# %% [markdown]
# # Read file

# %%
input_df = pd.read_excel('data/MPI_Directory_by_Establishment_Name_1.xls')

# %%
input_df.head()
# Out:
#          EstNumber                                 Company  \
# 0  M13561 + P13561                   165368 C. Corporation
# 1  M53869 + P53869           1845 Smoked Meat Company, LLC
# 2           M47086                              1923 Chili
# 3    M7067 + P7067  1st Original Texas Chili Company, Inc.
# 4  M48294 + P48294                           210 Foods LLC
#
#                         Street           City State    Zip           Phone  \
# 0  5617 Hoover Street, Suite A        Houston    TX  77092  (713) 263-1944
# 1       1555 North Business 35  New Braunfels    TX  78130  (210) 378-1911
# 2           2712 Wilmington Rd     New Castle    PA  16105  (724) 657-7151
# 3         3313 N. Jones Street     Fort Worth    TX  76106  (817) 626-0983
# 4                53 Kinder Dr.    San Antonio    TX  78212  (210) 277-0732
#
#     GrantDate                           Activities                      DBAs
# 0  06/30/2014                      Meat Processing  Long Phung Food Products
# 1  10/25/2021  Meat Processing, Poultry Processing                       NaN
# 2  12/12/2019                      Meat Processing                       NaN
# 3  11/28/2003                      Meat Processing   T.C. Foods; Texas Chili
# 4  11/16/2017  Meat Processing, Poultry Processing                 210 Foods

# %%
input_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6649 entries, 0 to 6648
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EstNumber   6649 non-null   object
#  1   Company     6649 non-null   object
#  2   Street      6649 non-null   object
#  3   City        6649 non-null   object
#  4   State       6649 non-null   object
#  5   Zip         6649 non-null   int64
#  6   Phone       6649 non-null   object
#  7   GrantDate   6602 non-null   object
#  8   Activities  6637 non-null   object
#  9   DBAs        2047 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 519.6+ KB

# %% [markdown]
# # Issues identified about the data
# - Some companies have multiple EstNumbers
# - Some companies have the same phone numbers (Phone) but different or slight variations in name spelling
# - Some company names have comma(,) others dont. **No consistency**
# - Some companies have multiple Activities
# - Some companies have Zip codes with less than 5 characters. **No consistency**
# - Some companies have multiple DBAs
#
#
# # Normalized Database
# The objective of this project is to download data, clean data, create a normalized database and dump clean data in database. As part of the normalization, individual tables need to be created and companies with multiple **EstNumbers**, multiple **Activities** and **DBAs** must have individual entries for each **EstNumbers**, **Activities**, and **DBAs**. More light will be thrown on this when we design the model for the database.

# %% [markdown]
# # Cleaning data

# %%
def remove_comma(text):
    if ',' in text:
        text = ' '.join(text.split(','))
        
    return text.lower()

# %%
def sep_name_dba_variants(text):
    # remove dba variants in company names
    identified = False
    if ' dba' in text.lower():
        identified = True
        names = text.split(' dba')
        
    if identified:
        return [name.strip() for name in names]
    else:
        return [text]

# %%
def remove_reg_type(text):
    # remove registration type from company names       
    hld = text.split(' ')
    for expr in ['llc', 'inc', 'limited', 'ltd', 'incorporated', 'corporation', 'corp', 'co', 'company']:
        if expr in hld:
            hld.remove(expr)
    return ' '.join(hld)

# %%
def remove_puncts(text):
    hld = text
    change = False
    for punct in ['.',':',';','(',')','"','/',',']:
        change = True
        if punct in hld:
            hld = hld.replace(punct,'').strip()
    if change:
        return hld
    else:
        text

# %%
def rename_companies_with_common_phone(df):
    raw_df = df.copy()
    phone_index = raw_df.Phone.value_counts(sort=True, ascending=False)[raw_df.Phone.value_counts() > 1].index
    if len(phone_index) > 1:
        rename_dict = {raw_df[raw_df.Phone == num].Company.value_counts().index[0]: \
                       raw_df[raw_df.Phone == num].index for num in phone_index}

    for k,v in rename_dict.items():
        for idx in v:
            raw_df.loc[idx, 'Company'] = k
    
    return raw_df

# %%
def homoginize_names(text, name_list):
    matches = difflib.get_close_matches(text, name_list, cutoff = 0.7, n=2)
    if len(matches) > 1:
        if text in matches[1]:
            return matches[1]
    return text

# %%
def separate_compound_names(text, joiner='/'):
    if joiner in text:
        return text.split(joiner)
    else:
        return text

# %%
def update_dba(name, index, df):
    if type(df.DBAs.loc[index]) != float:
        df.loc[index, 'DBAs'] = df.DBAs.loc[index] +'; ' + name

    else:
        df.loc[index, 'DBAs'] = name

# %%
def separate_loc_names(text):
    for expr in [' - ', ' -- ']:
        if expr in text:
            return text.split(expr)[0].strip()
    return text

# %%
def clean_zip(text):
    return str(text).zfill(5)

# %%
def separate_est_num(dba, est_lst):
    hld = dba.split(' ')
    for num in est_lst:
        if num in hld:
            hld.remove(num)
    if len(hld) != 0:
        return ' '.join(hld)
    return None

# %%
def clean_company_names(idx, row, raw_df):
    
    # Separating compound company names
    comp_name = separate_compound_names(row.Company)
    if type(comp_name) == list:
        comp_name = comp_name[0]
        update_dba(comp_name, idx, raw_df)
    comp_name = comp_name.lower()

    # remove undesiredd punctuations
    raw_df.loc[idx, 'Company'] = remove_puncts(comp_name)

    # Separate dba variants in names
    names = sep_name_dba_variants(raw_df.loc[idx, 'Company'])
    # Update company name
    raw_df.loc[idx, 'Company'] = names[0]
    # Update DBAs
    if len(names) > 2:
        update_dba(names[0], idx, raw_df)

    # remove registration type from company names       
    raw_df.loc[idx, 'Company'] = remove_reg_type(raw_df.loc[idx, 'Company'])

    # remove location from company names
    raw_df.loc[idx, 'Company'] = separate_loc_names(raw_df.loc[idx, 'Company'])

# %%
def extract(row, con, col, hld_dict):
    if type(row[col]) != float:
        if con in row[col]:
            hld_dict[col].append(row[col].split(con))
        else:
            hld_dict[col].append([row[col]])
    else:
         hld_dict[col].append(list())

# %%
def extract_est_num(row, est_dict):
    if '+' in row.EstNumber:
        est_list = [est.strip() for est in row.EstNumber.split('+')]
        for x in range(len(est_list)):
            est_dict['EstNumber'].append(est_list[x])
    else:
        est_dict['EstNumber'].append(row.EstNumber)

# %%
def extract_activities(row):
    if '+' in row.EstNumber:
        est_list = [est.strip() for est in r.EstNumber.split('+')]
        for x in range(len(est_list)):
            est_dict['EstNumber'].append(est_list[x])
    else:
        est_dict['EstNumber'].append(row.EstNumber)

# %%
def clean_dba(i, dba_dict):    
    # Separate compound names
    hld_ = dba_dict['DBAs'][i]
    hld_i = dba_dict['DBAs'][i].copy()
    if len(hld_) > 0:
        for dba in hld_:
            hld_name = separate_compound_names(dba)
            if type(hld_name) == list:
                hld_i.remove(dba)
                hld_i.extend(hld_name)
                dba_dict['DBAs'][i] = hld_i
                
    dba_dict['DBAs'][i] = [dba.strip().lower() for dba in dba_dict['DBAs'][i]]
    
    # Remove undesired punctuations
    dba_dict['DBAs'][i] = [remove_puncts(dba) for dba in dba_dict['DBAs'][i]]
    
    # Remove registration type
    dba_dict['DBAs'][i] = [remove_reg_type(dba) for dba in dba_dict['DBAs'][i]]
    
    # Remove location from names
    dba_dict['DBAs'][i] = [separate_loc_names(dba) for dba in dba_dict['DBAs'][i]]
    
    # Remove estsblishment numbers from dbas
    est_lst=[i.strip().lower() for i in input_df.EstNumber[i].split('+')]
    dba_dict['DBAs'][i] = [separate_est_num(dba, est_lst).strip() for dba in dba_dict['DBAs'][i] if separate_est_num(dba, est_lst) != None]

# %%
def homogenize_dict(i, hld_dict, name_list, col):
    hld_dict[col][i] = [homoginize_names(dba, name_list) for dba in hld_dict[col][i]]

# %%
def homogenize_company_names(index, raw_df, company_list):
    matched_name = homoginize_names(raw_df.loc[index, 'Company'], company_list)
    if raw_df.loc[index, 'Company'] != matched_name:
        raw_df.loc[index, 'Company'] = matched_name
    else:
        raw_df.loc[index, 'Company'] = matched_name

# %%
def creat_val_df(df, col_slice, val_list, val_col):
    hld_dict = {col:[] for col in col_slice}
    update_col = col_slice.copy()
    update_col.remove(val_col)
    
    for idx in df.index:
        for i in range(len(val_list[idx])):
            for col in update_col:
                hld_dict[col].append(df[col][idx])
            
            hld_dict[val_col].append(val_list[idx][i].strip())
            
    return pd.DataFrame(hld_dict)

# %%
def create_business_df(df, unique_cols):
    vals= df[unique_cols].value_counts(sort=False).index
    cols = df[unique_cols].value_counts(sort=False).index.names
    data = [((tup[0]),(tup[1]),(tup[2]),(tup[3]),(tup[4])) for tup in vals]

    return pd.DataFrame(data=data, columns=cols)

# %%
def clean_data(df, unique_cols=['Company', 'Street', 'City', 'State', 'Zip']):
    raw_df = df.copy()
    
    dba_col_slice = unique_cols.copy()
    dba_col_slice.append('DBAs')
    dba_dict = {'DBAs':[]}
    
    est_col_slice = unique_cols.copy()
    est_col_slice.append('EstNumber')
    est_col_slice.append('GrantDate')
    est_dict = {'EstNumber':[]}
    
    act_col_slice = unique_cols.copy()
    act_col_slice.append('Activities')
    act_dict = {'Activities':[]}
    
    phone_col_slice = unique_cols.copy()
    phone_col_slice.append('Phone')
    
    print('Separating compound company names...\nRemoving undesiredd punctuations...', \
          '\nSeparating dba variants in names...\nRemoving registration type from company names...', \
          '\nExtracting DBAs...\n')
    for idx,row in df.iterrows():
        
        # clean company names
        clean_company_names(idx, row, raw_df)
        
        # extract dbas 
        extract(row, con=';', col='DBAs', hld_dict=dba_dict)
            
        # extract Activities 
        extract(row, con=',', col='Activities', hld_dict=act_dict)
        
        # Clean Zip
        raw_df.loc[idx, 'Zip'] = clean_zip(raw_df.loc[idx, 'Zip'])
        
        # Extract Establishment number
        extract(row, con='+', col='EstNumber', hld_dict=est_dict)
    
    
    for i in range(len(dba_dict['DBAs'])):
        # clean dba
        clean_dba(i, dba_dict)
    
    name_list = set([act for _ in act_dict['Activities'] for act in _])
    company_list = set([dba_ for dba in dba_dict['DBAs'] for dba_ in dba]).union(set(raw_df.Company.values))
    for index in raw_df.index:
        #homogenize dbas
        homogenize_dict(i=index, hld_dict=dba_dict, name_list=company_list, col='DBAs')
        
        #homogenize activities
        homogenize_dict(i=index, hld_dict=act_dict, name_list=company_list, col='Activities')
    
        # homogenize names
        homogenize_company_names(index=index, raw_df=raw_df, company_list=company_list)
        
        if index %100 == 0 or index == 0:
            print('Homogenizing company names and DBAs...\nIndex: ',index,'/',len(raw_df), \
                  '\nCompany: ',raw_df.loc[index, 'Company'], '\nDBAs: ',dba_dict['DBAs'][index],'\n')
    
    
    # create df of dba_dict
    dba_df = creat_val_df(df=raw_df, col_slice=dba_col_slice, val_list=dba_dict['DBAs'], val_col='DBAs')
    
    # create df of est_dict
    est_df = creat_val_df(df=raw_df, col_slice=est_col_slice, val_list=est_dict['EstNumber'], val_col='EstNumber')
    
    # create df of act_dict
    act_df = creat_val_df(df=raw_df, col_slice=act_col_slice, val_list=act_dict['Activities'], val_col='Activities')
    
    # create df for business
    business_df = create_business_df(df=raw_df, unique_cols=unique_cols)
    
    # create df for phone numbers
    phone_df = business_df.merge(raw_df[phone_col_slice], on=unique_cols)
    
    return dba_df, est_df, act_df, business_df, phone_df

# %%
out_dfs = clean_data(input_df)
# Out:
# Separating compound company names...
# Removing undesiredd punctuations...
# Separating dba variants in names...
# Removing registration type from company names...
# Extracting DBAs...
#
# Homogenizing company names and DBAs...
# Index:  0 / 6649
# Company:  165368 c
# DBAs:  ['long phung food products']
#
# Homogenizing company names and DBAs...
# Index:  100 / 6649
# Company:  abe manufacturing
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  200 / 6649
# Company:  aliyans global
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  300 / 6649
# Company:  americold logistics
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  400 / 6649
# Company:  andy's meats
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  500 / 6649
# Company:  b&a gourment food
# DBAs:  ["abuela's gourmet kitchen", 'america food services', 'big ranch beef', 'charlie steak house', 'corte argentino', 'goya', 'la toca blanca', 'mambo', 'menu art', 'natura foods', "nature's cut", 'tradiciones andinas', 'wild fork foods']
#
# Homogenizing company names and DBAs...
# Index:  600 / 6649
# Company:  beef jerky unlimited
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  700 / 6649
# Company:  blue chip group
# DBAs:  ['augason farms', 'emergency essentials', 'live prepared']
#
# Homogenizing company names and DBAs...
# Index:  800 / 6649
# Company:  brushy prairie packing
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  900 / 6649
# Company:  cpk quality foods
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  1000 / 6649
# Company:  cargill meat solutions
# DBAs:  ['cargill beef', 'cargill protein group', 'excel', 'mbpxl', 'xl']
#
# Homogenizing company names and DBAs...
# Index:  1100 / 6649
# Company:  century packing
# DBAs:  ['carmela sausages', 'salchichas carmela']
#
# Homogenizing company names and DBAs...
# Index:  1200 / 6649
# Company:  classic delight
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  1300 / 6649
# Company:  contes pasta
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  1400 / 6649
# Company:  crystal distribution services
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  1500 / 6649
# Company:  dandy distributors
# DBAs:  ['dandy foods']
#
# Homogenizing company names and DBAs...
# Index:  1600 / 6649
# Company:  dipaola turkeys
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  1700 / 6649
# Company:  e-hwa food products
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  1800 / 6649
# Company:  empacadora y procesadora del sur
# DBAs:  ['chef pineiro', 'econo', 'empacadora y procesadora del sur', 'emperador', 'emprosur', 'great value', 'quiquiri kirch', 'selectos', 'taco maker', "valeria's", "wendy's"]
#
# Homogenizing company names and DBAs...
# Index:  1900 / 6649
# Company:  faribault foods
# DBAs:  ['faribault foods']
#
# Homogenizing company names and DBAs...
# Index:  2000 / 6649
# Company:  food ingredients technology
# DBAs:  ['fitco', 'idf international dehydrated foods']
#
# Homogenizing company names and DBAs...
# Index:  2100 / 6649
# Company:  fresh mark cold storage
# DBAs:  ['fresh mark', 'stark provision', 'sugardale foods', 'superior brand meats']
#
# Homogenizing company names and DBAs...
# Index:  2200 / 6649
# Company:  general snack foods
# DBAs:  ['fresh foods']
#
# Homogenizing company names and DBAs...
# Index:  2300 / 6649
# Company:  golden plains frozen foods
# DBAs:  ['amazatto', 'golden plains frozen foods', 'roseli', 'zalvina']
#
# Homogenizing company names and DBAs...
# Index:  2400 / 6649
# Company:  green's quality meats
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  2500 / 6649
# Company:  hardison's carolina barbecue
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  2600 / 6649
# Company:  hickory hollow jerky
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  2700 / 6649
# Company:  husnik meat
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  2800 / 6649
# Company:  isabelle's kitchen
# DBAs:  ['jersey side salads', 'salad bar salads', 'salad bar tenders', 'salad specialties']
#
# Homogenizing company names and DBAs...
# Index:  2900 / 6649
# Company:  jwm distribution
# DBAs:  ['jwm distribution']
#
# Homogenizing company names and DBAs...
# Index:  3000 / 6649
# Company:  jones meat & food services
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  3100 / 6649
# Company:  kentucky farm kitchens
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  3200 / 6649
# Company:  kraft heinz foods
# DBAs:  ['kraft foods group', 'kraft heinz food']
#
# Homogenizing company names and DBAs...
# Index:  3300 / 6649
# Company:  laredo cold storage
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  3400 / 6649
# Company:  lineage logistics pfs
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  3500 / 6649
# Company:  local cuts meat
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  3600 / 6649
# Company:  mg foods
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  3700 / 6649
# Company:  martin preferred foods lp
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  3800 / 6649
# Company:  mendez &
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  3900 / 6649
# Company:  mineola packing
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  4000 / 6649
# Company:  mr j's tamales & chili
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  4100 / 6649
# Company:  nelson's meat processing
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  4200 / 6649
# Company:  norsan meats
# DBAs:  ['norsan meats', 'prime meats']
#
# Homogenizing company names and DBAs...
# Index:  4300 / 6649
# Company:  old trapper smoked products
# DBAs:  ['mountain man', 'verboort']
#
# Homogenizing company names and DBAs...
# Index:  4400 / 6649
# Company:  pj food service
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  4500 / 6649
# Company:  paumie's porkies
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  4600 / 6649
# Company:  piedmont bbbq
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  4700 / 6649
# Company:  potts family meats
# DBAs:  ['georgia meat packers']
#
# Homogenizing company names and DBAs...
# Index:  4800 / 6649
# Company:  pulmuone foods usa
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  4900 / 6649
# Company:  ragozzino foods
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  5000 / 6649
# Company:  rich products
# DBAs:  ["byron's bbq", 'rich products']
#
# Homogenizing company names and DBAs...
# Index:  5100 / 6649
# Company:  ruwaldt packing
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  5200 / 6649
# Company:  sanderson farms processing div
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  5300 / 6649
# Company:  shamrock foods
# DBAs:  ['gold canyon meat']
#
# Homogenizing company names and DBAs...
# Index:  5400 / 6649
# Company:  smithfield fresh meats sales
# DBAs:  ['814 americas', 'aberdeen', 'agar foods', 'american farms', 'ark valley', 'armour', 'armour eckrich meats', 'armour foods', 'carando', 'clougherty packing', "cook's ham", "cook's ham", 'country lean', "curly's", "curly's foods", 'decker food', 'eastbay packing', 'eckrich', 'farmer john egg', 'farmland', 'farmland foods', 'farmstead', 'fj foodservice', 'golden crisp premium foods', 'gwaltney', 'healthy ones', 'hunter krey packing', 'hunter packing', 'jamestown', 'john morrell', 'john morrell &', 'kansas city sausage', 'kneip', 'krakus', 'krakus foods international', 'kretschmar', 'kretschmar brands', 'kretschmar deli', 'krey packing', 'lakeview', "lundy's", 'maple river brand', 'margherita', 'mohawk packing', 'mohawk provision', 'moseys', 'moyer packing', 'northside foods', 'ohse', 'partridge meats', 'patrick cudahy', 'patrick cudahy', 'peyton packing', 'pine ridge farms', 'premium farms', 'premium pet health', 'premium standard farms', 'pruden packing', 'pure farms', 'quick-to-fix', 'racorn', 'rath blackhawk', 'rodeo meats', 'rodeo meats', 'roegelein', "saag's products", 'selective petfood services', 'smithfield pet', 'smithfield farmland', 'smithfield farmland sales', 'smithfield foods', 'smithfield foods', 'smithfield fresh meats sales', 'smithfield fresh meats sales', 'smithfield fresh meats sales', 'smithfield packaged meats', 'smithfield packaged meats sales', 'the smithfield packing', 'smithfield pet', 'spring hill brand', 'stefano foods', "stefano's", 'sweet applewood farms', 'the smithfield packing', 'tiffany springs packing', "tobin's first prize meat", 'valleydale', 'village butcher', 'windsor foods']
# Homogenizing company names and DBAs...
# Index:  5500 / 6649
# Company:  southwest processor
# DBAs:  ['kot']
#
# Homogenizing company names and DBAs...
# Index:  5600 / 6649
# Company:  stormberg foods
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  5700 / 6649
# Company:  sysco western minnesota
# DBAs:  ["appert's foodservice", 'buckhead meats of minnesota']
#
# Homogenizing company names and DBAs...
# Index:  5800 / 6649
# Company:  texas tech university gordon w davis meat science laboratory
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  5900 / 6649
# Company:  thibodeaux's cajun food
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  6000 / 6649
# Company:  truitt bros
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  6100 / 6649
# Company:  tyson prepared foods
# DBAs:  ['tyson deli', 'tyson foodsinc', 'tyson sales and distribution']
#
# Homogenizing company names and DBAs...
# Index:  6200 / 6649
# Company:  united states cold storage lp
# DBAs:  ['united states cold storage lp']
#
# Homogenizing company names and DBAs...
# Index:  6300 / 6649
# Company:  vie de france bakery yamazaki
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  6400 / 6649
# Company:  watkins ranch butcher shop
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  6500 / 6649
# Company:  white oak pastures
# DBAs:  []
#
# Homogenizing company names and DBAs...
# Index:  6600 / 6649
# Company:  yants snack foods
# DBAs:  []

# %%
out_dfs[4]
# Out:
#                         Company                             Street  \
# 0                      165368 c        5617 Hoover Street, Suite A
# 1              1845 smoked meat             1555 North Business 35
# 2                    1923 chili                 2712 Wilmington Rd
# 3      1st original texas chili               3313 N. Jones Street
# 4                     210 foods                      53 Kinder Dr.
# ...                         ...                                ...
# 6644                 zummo meat               3705 St. James Blvd.
# 6645    zuppardi's frozen foods                    214 Main Street
# 6646  zwanenberg food group usa              3640 Muddy Creek Road
# 6647                  zweigle's             651 Plymouth Ave North
# 6648            zyk enterprises  17658 W. Snoqualmie River Road NE
#
#                City State    Zip           Phone
# 0           Houston    TX  77092  (713) 263-1944
# 1     New Braunfels    TX  78130  (210) 378-1911
# 2        New Castle    PA  16105  (724) 657-7151
# 3        Fort Worth    TX  76106  (817) 626-0983
# 4       San Antonio    TX  78212  (210) 277-0732
# ...             ...   ...    ...             ...
# 6644       Beaumont    TX  77705  (409) 842-1810
# 6645     West Haven    CT  06516  (203) 980-0392
# 6646     Cincinnati    OH  45238  (513) 682-6000
# 6647      Rochester    NY  14608  (585) 546-1740
# 6648         Duvall    WA  98019  (425) 788-1128
#
# [6649 rows x 6 columns]

# %%
for val in input_df.Activities.values:
    print(val,'\n')
# Out:
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Exotic, Voluntary Processing - Meat, Voluntary Slaughter - Exotic, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Animal Foods Inspection, Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Poultry Processing
#
# Certification - Export
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry, Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Identification - Meat, Identification - Poultry, Meat Processing, Poultry Processing, Voluntary Processing - Exotic, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Processing -
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Imported Product
#
# Imported Product
#
# Meat Processing, Poultry Processing
#
# Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Meat Slaughter
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Technical Animal Fats
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Egg Product
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Identification - Meat, Identification - Poultry
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Identification - Meat, Identification - Poultry, Off-Premise Freezing - Poultry
#
# AMS RTE Canada EV Program, Certification - Export, Food Inspection, Meat Processing, Poultry Processing
#
# Certification - Export
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# AMS RTE Canada EV Program, Certification - Export, Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry, Meat Processing, Poultry Processing
#
# AMS RTE Canada EV Program, Certification - Export, Food Inspection, Meat Processing, Poultry Processing
#
# Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry, Meat Processing, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Poultry Processing
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter
#
# Certification - Export, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Meat Processing, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Off-Premise Freezi
#
# Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Egg Products, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing
#
# Poultry Processing
#
# Poultry Processing
#
# Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry, Identification - Siluriformes
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Exotic, Voluntary Processing - Meat, Voluntary Slaughter - Exotic, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Certification - Export
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Voluntary Processing - Meat
#
# Poultry Processing
#
# Poultry Processing, Poultry Slaughter
#
# Identification - Meat, Identification - Poultry, Off-Premise Freezing - Egg Products, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Meat Processing, Poultry Processing
#
# Poultry Processing, Poultry Slaughter
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Food Inspection, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Cysticercus, Certification - Export, Food Inspection, Identification - Meat, Off-Premise Freezing - Meat
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Identification - Meat, Identification - Poultry
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Identification - Meat, Identification - Poultry
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter
#
# Certification - Export, Identification - Meat
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Egg Product
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Egg Product, Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Egg Product, Meat Processing, Poultry Processing
#
# Imported Product
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Off-Premise Freezing - Siluriformes
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Off-Prem
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Off-Prem
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Off-Prem
#
# Certification - Export
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Imported Product
#
# Imported Product
#
# Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Meat Processing, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Poultry Processing
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Food Inspection, Identification - Poultry
#
# nan
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Certification - Trichinae, Food Inspection, Identification - Meat, Identification - Poultry
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Egg Products, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Meat Processing, Poultry Processing
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Egg Products, Off-Premise Freezing - Meat, Off-P
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Egg Products, Off-Premise Freezing - Meat, Off-P
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Egg Products, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Egg Products, Off-Premise Freezing - Meat, Off-P
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Egg Products, Off-Premise Freezing - Meat, Off-P
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Egg Products, Off-Premise Freezing - Meat, Off-P
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# nan
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Imported Product
#
# Meat Processing, Poultry Processing
#
# Imported Product
#
# Imported Product
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Imported Product
#
# Imported Product
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Egg Products, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Meat Processing, Off-Premise Freezing - Egg Products, Off-Premise Freez
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Animal Foods Inspection, Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Egg Products, Off-Premi
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Egg Products, Off-Premise Freezing - Meat, Off-P
#
# Imported Product
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry
#
# Certification - Export
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Off-Premise Freezing - Egg Products, Off-Premise Freezing - Meat, Off
#
# Certification - Export, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Off-Premise Freezing - Siluriformes
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Off-Premise Freezing - Siluriformes
#
# Certification - Export, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Off-Premise Freezing - Siluriformes
#
# Certification - Export, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Off-Premise Freezing - Siluriformes
#
# Certification - Export, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Off-Premise Freezing - Siluriformes
#
# Certification - Export
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Poultry Processing, Poultry Slaughter
#
# Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing, Voluntary Processing - Exotic, Voluntary Processing - Meat, Voluntary Processing - Rabbit
#
# Meat Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Identification - Meat, Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Poultry Processing
#
# Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# nan
#
# Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat, Voluntary Slaughter - Rabbit
#
# Meat Processing, Meat Slaughter
#
# Animal Foods Inspection, Meat Processing, Poultry Processing
#
# Meat Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry, Meat Processing, Poultry Processing, Voluntary Processing - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry, Meat Processing, Off-Premise Freezing - Poultry, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat, Voluntary Processing - Rabbit
#
# Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Imported Product
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Identification - Siluriformes, Meat Processing, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Off-Premise Freezi
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Imported Product
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Identification - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Voluntary Processing - Meat
#
# Imported Product
#
# Certification - Export
#
# Meat Processing, Poultry Processing
#
# Imported Product
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Meat Processing, Meat Slaughter, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Identification - Meat, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Poultry Processing
#
# Meat Processing
#
# Animal Foods Inspection, Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Poultry Processing, Poultry Slaughter
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Certification - Export, Identification - Meat, Identification - Poultry, Imported Product
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Poultry Processing, Poultry Slaughter, Voluntary Processing - Poultry, Voluntary Slaughter - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Meat Processing
#
# Egg Product
#
# Imported Product
#
# Imported Product
#
# Certification - Export, Identification - Meat, Identification - Poultry, Identification - Siluriformes
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Certification - Export
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Slaughter
#
# Identification - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Certification - Trichinae, Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Slaughter - Meat, Voluntary Sl
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Food Inspection, Meat Processing, Poultry Processing, Voluntary Processing - Poultry
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Certification - Cysticercus, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Certification - Export
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export
#
# Meat Processing, Poultry Processing
#
# Identification - Meat, Identification - Poultry, Meat Processing, Poultry Processing
#
# Imported Product
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Exotic, Voluntary Processing - Meat, Voluntary Slaughter - Exotic, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Identification - Meat, Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Certification - Export
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# AMS RTE Canada EV Program, Food Inspection, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Processing - Poultry
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Voluntary Slaughter - Meat, Voluntary Slaughter - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Certification - Export, Egg Product, Voluntary Processing - Egg Products
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter
#
# Certification - Export, Meat Processing, Poultry Processing, Voluntary Processing - Exotic, Voluntary Processing - Meat, Voluntary Processing - Rabbit
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing, Poultry Processing, Poultry Slaughter
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Identification - Meat, Identification - Poultry, Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Processi
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Egg Product, Voluntary Processing - Egg Products
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Egg Product, Meat Processing, Poultry Processing
#
# Egg Product, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat
#
# Certification - Export, Identification - Meat
#
# Identification - Meat, Meat Processing, Meat Slaughter, Voluntary Processing - Rabbit, Voluntary Slaughter - Meat, Voluntary Slaughter - Rabbit
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Animal Foods Inspection, Meat Processing, Poultry Processing, Voluntary Processing - Exotic
#
# Meat Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Poultry Slaughter
#
# Meat Slaughter
#
# Certification - Export, Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Poultry Processing
#
# Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat, Voluntary Slaughter - Exotic, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat, Voluntary Processing - Poultry
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Processing - Rabbit
#
# Imported Product
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Identification - Meat, Identification - Poultry, Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Poultry Processing, Poultry Slaughter, Voluntary Processing - Poultry, Voluntary Slaughter - Poultry
#
# Meat Processing, Meat Slaughter, Voluntary Slaughter - Meat
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Poultry, Voluntary Processing - Rabbit, Voluntary Slaughter - Poultry, Voluntary Slaughter - Rabbit
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Processing - Rabbit
#
# Meat Processing, Poultry Processing, Voluntary Processing - Poultry
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# AMS RTE Canada EV Program, Certification - Export, Food Inspection, Identification - Meat, Identification - Poultry, Meat Processing, Poultry Processing
#
# AMS RTE Canada EV Program, Certification - Export, Food Inspection, Identification - Meat, Identification - Poultry, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Voluntary Processing - Meat
#
# Poultry Processing, Poultry Slaughter
#
# Certification - Export, Identification - Meat, Identification - Poultry, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Exotic, Voluntary Processing - Meat, Voluntary Processing - Rabbit, Voluntary Slaughter - Exotic, Voluntary Slaughter - Meat
#
# Certification - Trichinae
#
# Meat Processing, Poultry Processing
#
# ...
#
# Meat Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat, Voluntary Slaughter - Rabbit
#
# Meat Processing
#
# Meat Processing, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Identification - Meat
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Processing - Rabbit, Voluntary Slaughter - Meat, Voluntary Slaughter - Poultry, Voluntary Sl
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Slaughter - Meat, Voluntary Slaughter - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# nan
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Identification - Meat, Identification - Poultry
#
# Meat Processing
#
# Meat Processing, Meat Slaughter
#
# Poultry Processing, Poultry Slaughter
#
# Poultry Processing, Poultry Slaughter
#
# Poultry Processing, Poultry Slaughter, Voluntary Processing - Poultry, Voluntary Slaughter - Poultry
#
# Poultry Processing, Poultry Slaughter
#
# Certification - Export, Poultry Processing, Poultry Slaughter
#
# Certification - Export, Off-Premise Freezing - Poultry, Poultry Processing, Poultry Slaughter
#
# Food Inspection, Identification - Meat, Identification - Poultry, Meat Processing, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry, Poultry Processing
#
# Poultry Processing
#
# Identification - Meat, Identification - Poultry, Meat Processing, Poultry Processing, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Slaughter - Meat, Voluntary Slaughter - Pou
#
# Poultry Processing, Poultry Slaughter
#
# Poultry Processing, Poultry Slaughter
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat, Voluntary Processing - Poultry
#
# Meat Processing
#
# Identification - Meat, Identification - Poultry
#
# Identification - Meat, Identification - Poultry
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry, Meat Processing, Poultry Processing, Voluntary Processing - Meat, Voluntary Processing - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry
#
# Imported Product
#
# Meat Processing, Poultry Processing
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Certification - Export
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Exotic, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Processing - Rabbit, Voluntary Slaughter - Exotic, Voluntary Slau
#
# Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Exotic, Voluntary Processing - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat, Voluntary Processing - Rabbit
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Voluntary Slaughter - Meat
#
# Certification - Export
#
# Voluntary Slaughter - Exotic, Voluntary Slaughter - Meat
#
# Meat Processing, Meat Slaughter
#
# Identification - Meat, Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat, Voluntary Slaughter - Rabbit
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Certification - Export
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Exotic, Voluntary Processing - Meat
#
# AMS RTE Canada EV Program, Certification - Export, Food Inspection, Identification - Meat, Identification - Poultry
#
# Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Certification - Export, Meat Processing, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Processing - Rabbit
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter
#
# Poultry Slaughter
#
# Certification - Export, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Slaughter - Meat, Voluntary Slaughter - Poultry
#
# Food Inspection, Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Exotic, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Slaughter
#
# Meat Processing, Poultry Processing
#
# Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Egg Product
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Egg Product
#
# Certification - Trichinae, Identification - Meat, Identification - Poultry, Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat, Voluntary Processing - Rabbit, Voluntary Slaughter - Poultry, Voluntary Slaughter - Rabbit
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter, Off-Premise Freezing - Meat, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Slaughter - Meat, Voluntary Slaughter - Poultry, Voluntar
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Processing - Rabbit, Voluntary Slaughter - Meat, Voluntary Slaughter - Poult
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing
#
# Certification - Cysticercus, Certification - Export, Certification - Trichinae, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Certification - Export
#
# Certification - Export
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Certification - Export, Identification - Meat, Off-Premise Freezing - Meat
#
# Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing
#
# Poultry Processing, Poultry Slaughter
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Poultry Processing, Poultry Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Slaughter - Meat, Voluntary Slaughter - Poultry
#
# Certification - Export, Identification - Meat
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Meat, Voluntary Processing - Poultry, Voluntary Slaughter - Meat, Voluntary Slaughter - Poultry
#
# Food Inspection, Meat Processing, Meat Slaughter, Voluntary Processing - Exotic, Voluntary Processing - Meat, Voluntary Slaughter - Exotic, Voluntary Slaughter - Meat
#
# Certification - Trichinae, Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Meat Slaughter, Voluntary Processing - Exotic, Voluntary Processing - Meat, Voluntary Slaughter - Exotic, Voluntary Slaughter - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Poultry, Voluntary Slaughter - Meat
#
# Certification - Export, Identification - Meat
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Food Inspection, Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Certification - Export, Identification - Meat
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Voluntary Processing - Meat
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Identification - Meat
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Exotic, Voluntary Processing - Meat
#
# Imported Product
#
# Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter, Poultry Processing, Voluntary Processing - Meat, Voluntary Slaughter - Meat
#
# Certification - Export, Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Animal Foods Inspection, Certification - Trichinae, Identification - Meat, Identification - Poultry, Off-Premise Freezing - Meat, Off-Premise Freezing - Poultry
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Certification - Export, Meat Processing, Meat Slaughter
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Certification - Export, Meat Processing, Meat Slaughter
#
# Meat Processing, Meat Slaughter, Poultry Processing, Poultry Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Certification - Export, Identification - Meat, Identification - Poultry
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Poultry Processing, Poultry Slaughter
#
# Meat Processing, Meat Slaughter
#
# Meat Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing
#
# Meat Processing, Poultry Processing, Voluntary Processing - Meat
#
# Identification - Meat, Identification - Poultry
#
# Meat Processing
#
# Identification - Meat, Identification - Poultry

# %%
ph = input_df.Phone.value_counts(sort=True, ascending=False)[input_df.Phone.value_counts() > 1]
assert len(set(input_df.Phone.unique())) - len(set(ph.index)) + ph.sum() == len(input_df)

# %%
len(input_df.Company.unique())
# Out:
# 5751

# %%
len(set(input_df.Company.apply(lambda x:x.lower())))
# Out:
# 5732
